# %%
id = "paddle"
output = f"/ssd2/liuyixin04/workspace/result-{id}.png"
trian_logdir = f"/ssd2/liuyixin04/workspace/logs/benchmark-{id}/train_log"

from tensorboard.backend.event_processing import event_accumulator
import argparse
import pandas as pd
from tqdm import tqdm
import os 
import time

def mkdir(path):
	folder = os.path.exists(path)
	if not folder:
		os.makedirs(path)

g = os.walk(trian_logdir)
ckpt = []
for path, dir_list, file_names in g:
    # print(path,dir_name,file_names)
    for dir_name in dir_list:
        # print()
        sub_path = os.path.join(path, dir_name)
        ckpt.append(sub_path)
        # break
    # break
    # for f in file_names:
    #     ckpt.append(os.path.join(path,f))

# ckpt=[f for f in ckpt if 'event' in f ]
# in_path='/ssd2/liuyixin04/workspace/PARL/examples/MADDPG/train_log/simple_3013_False'
for in_path in tqdm(ckpt):
    print(input)
    event_data = event_accumulator.EventAccumulator(in_path)  # a python interface for loading Event data
    event_data.Reload()  # synchronously loads all of the data written so far b
    df = pd.DataFrame(event_data.Scalars('mean_episode_reward/episode'))
    df.columns = ['Wall_time', 'Step', 'Value']
    df.to_csv(f'{in_path}/data.csv',index=False)
    print(in_path)
    # break

# create dir
root = f'/ssd2/liuyixin04/workspace/logs/tmp/{id}-tmp-{time.time()}'
mkdir(root)
algs = ['MADDPG-continous','MADDPG-discrete']
for alg in algs:
    mkdir(os.path.join(root,alg))
envs = [
        'simple', 'simple_adversary', 'simple_crypto', 'simple_push',
        'simple_speaker_listener', 'simple_spread', 'simple_tag',
        'simple_world_comm'
    ]
for alg in algs:
    for env in envs:
        path=os.path.join(root,alg)
        mkdir(os.path.join(path,env))
datalist = [f+'/data.csv' for f in ckpt]
flaglist = [d.split('/')[-2] for d in datalist]
flaglist
for i,csv in enumerate(datalist):
    path = root
    if 'True' in flaglist[i]:
        path=os.path.join(path,'MADDPG-continous')
    else:
        path=os.path.join(path,'MADDPG-discrete')
    path = os.path.join(path,'_'.join(flaglist[i].split('_')[:-2]))
    # '/'.join(csv.split('/')[:-1])
    csv_old = os.path.join(path,'data.csv')
    csv_new = csv_old.replace('data','_'.join(flaglist[i].split('_')[-2:]))
    # os.system(f"rm {csv_old}")
    os.system(f'cp {csv} {path}')
    os.system(f"mv {csv_old} {csv_new}")
os.system(f'/opt/compiler/gcc-8.2/lib/ld-linux-x86-64.so.2 --library-path /opt/compiler/gcc-8.2/lib:/usr/lib64:/ssd2/liuyixin04/miniconda3/envs/py37_paddle/lib:/home/work/cuda-10.0/lib64/:/home/work/cudnn_v7.4/cuda/lib64/:/ssd2/liuyixin04/.jumbo/lib /ssd2/liuyixin04/miniconda3/envs/py37_paddle/bin/python /ssd2/liuyixin04/workspace/my-repo-yixin/auto-plot-yixin/result-drawing-master/draw_benchmark.py --path {root} --output {output}')
# os.system(f'rm -r {root}')
# Out:
# se
# <bound method Kernel.raw_input of <ipykernel.ipkernel.IPythonKernel object at 0x7f905e314a30>>
#  48%|████▊     | 31/64 [01:30<01:04,  1.94s/it]/ssd2/liuyixin04/workspace/logs/benchmark-paddle/train_log/simple_crypto_24475_False
# <bound method Kernel.raw_input of <ipykernel.ipkernel.IPythonKernel object at 0x7f905e314a30>>
#  50%|█████     | 32/64 [01:32<00:55,  1.74s/it]/ssd2/liuyixin04/workspace/logs/benchmark-paddle/train_log/simple_adversary_18326_True
# <bound method Kernel.raw_input of <ipykernel.ipkernel.IPythonKernel object at 0x7f905e314a30>>
#  52%|█████▏    | 33/64 [01:33<00:49,  1.60s/it]/ssd2/liuyixin04/workspace/logs/benchmark-paddle/train_log/simple_crypto_18326_False
# <bound method Kernel.raw_input of <ipykernel.ipkernel.IPythonKernel object at 0x7f905e314a30>>
#  53%|█████▎    | 34/64 [01:34<00:44,  1.48s/it]/ssd2/liuyixin04/workspace/logs/benchmark-paddle/train_log/simple_speaker_listener_18326_True
# <bound method Kernel.raw_input of <ipykernel.ipkernel.IPythonKernel object at 0x7f905e314a30>>
#  55%|█████▍    | 35/64 [01:41<01:28,  3.06s/it]/ssd2/liuyixin04/workspace/logs/benchmark-paddle/train_log/simple_world_comm_18326_False
# <bound method Kernel.raw_input of <ipykernel.ipkernel.IPythonKernel object at 0x7f905e314a30>>
#  56%|█████▋    | 36/64 [01:46<01:44,  3.74s/it]/ssd2/liuyixin04/workspace/logs/benchmark-paddle/train_log/simple_spread_20135_False
# <bound method Kernel.raw_input of <ipykernel.ipkernel.IPythonKernel object at 0x7f905e314a30>>
#  58%|█████▊    | 37/64 [01:48<01:21,  3.03s/it]/ssd2/liuyixin04/workspace/logs/benchmark-paddle/train_log/simple_crypto_24475_True
# <bound method Kernel.raw_input of <ipykernel.ipkernel.IPythonKernel object at 0x7f905e314a30>>
#  59%|█████▉    | 38/64 [01:49<01:05,  2.50s/it]/ssd2/liuyixin04/workspace/logs/benchmark-paddle/train_log/simple_18326_True
# <bound method Kernel.raw_input of <ipykernel.ipkernel.IPythonKernel object at 0x7f905e314a30>>
#  61%|██████    | 39/64 [01:56<01:33,  3.74s/it]/ssd2/liuyixin04/workspace/logs/benchmark-paddle/train_log/simple_world_comm_18326_True
# <bound method Kernel.raw_input of <ipykernel.ipkernel.IPythonKernel object at 0x7f905e314a30>>
#  62%|██████▎   | 40/64 [02:02<01:52,  4.69s/it]/ssd2/liuyixin04/workspace/logs/benchmark-paddle/train_log/simple_world_comm_30844_True
# <bound method Kernel.raw_input of <ipykernel.ipkernel.IPythonKernel object at 0x7f905e314a30>>
#  64%|██████▍   | 41/64 [02:04<01:25,  3.72s/it]/ssd2/liuyixin04/workspace/logs/benchmark-paddle/train_log/simple_adversary_30844_False
# <bound method Kernel.raw_input of <ipykernel.ipkernel.IPythonKernel object at 0x7f905e314a30>>
#  66%|██████▌   | 42/64 [02:05<01:05,  2.97s/it]/ssd2/liuyixin04/workspace/logs/benchmark-paddle/train_log/simple_speaker_listener_20135_True
# <bound method Kernel.raw_input of <ipykernel.ipkernel.IPythonKernel object at 0x7f905e314a30>>
#  67%|██████▋   | 43/64 [02:06<00:51,  2.47s/it]/ssd2/liuyixin04/workspace/logs/benchmark-paddle/train_log/simple_adversary_20135_False
# <bound method Kernel.raw_input of <ipykernel.ipkernel.IPythonKernel object at 0x7f905e314a30>>
#  69%|██████▉   | 44/64 [02:08<00:42,  2.14s/it]/ssd2/liuyixin04/workspace/logs/benchmark-paddle/train_log/simple_adversary_20135_True
# <bound method Kernel.raw_input of <ipykernel.ipkernel.IPythonKernel object at 0x7f905e314a30>>
#  70%|███████   | 45/64 [02:09<00:36,  1.90s/it]/ssd2/liuyixin04/workspace/logs/benchmark-paddle/train_log/simple_speaker_listener_24475_True
# <bound method Kernel.raw_input of <ipykernel.ipkernel.IPythonKernel object at 0x7f905e314a30>>
#  72%|███████▏  | 46/64 [02:10<00:30,  1.70s/it]/ssd2/liuyixin04/workspace/logs/benchmark-paddle/train_log/simple_speaker_listener_18326_False
# <bound method Kernel.raw_input of <ipykernel.ipkernel.IPythonKernel object at 0x7f905e314a30>>
#  73%|███████▎  | 47/64 [02:17<00:54,  3.21s/it]/ssd2/liuyixin04/workspace/logs/benchmark-paddle/train_log/simple_world_comm_30844_False
# <bound method Kernel.raw_input of <ipykernel.ipkernel.IPythonKernel object at 0x7f905e314a30>>
#  75%|███████▌  | 48/64 [02:18<00:42,  2.64s/it]/ssd2/liuyixin04/workspace/logs/benchmark-paddle/train_log/simple_crypto_18326_True
# <bound method Kernel.raw_input of <ipykernel.ipkernel.IPythonKernel object at 0x7f905e314a30>>
#  77%|███████▋  | 49/64 [02:24<00:54,  3.62s/it]/ssd2/liuyixin04/workspace/logs/benchmark-paddle/train_log/simple_tag_18326_False
# <bound method Kernel.raw_input of <ipykernel.ipkernel.IPythonKernel object at 0x7f905e314a30>>
#  78%|███████▊  | 50/64 [02:30<00:59,  4.24s/it]/ssd2/liuyixin04/workspace/logs/benchmark-paddle/train_log/simple_tag_20135_False
# <bound method Kernel.raw_input of <ipykernel.ipkernel.IPythonKernel object at 0x7f905e314a30>>
#  80%|███████▉  | 51/64 [02:31<00:43,  3.37s/it]/ssd2/liuyixin04/workspace/logs/benchmark-paddle/train_log/simple_speaker_listener_30844_True
# <bound method Kernel.raw_input of <ipykernel.ipkernel.IPythonKernel object at 0x7f905e314a30>>
#  81%|████████▏ | 52/64 [02:33<00:32,  2.74s/it]/ssd2/liuyixin04/workspace/logs/benchmark-paddle/train_log/simple_crypto_20135_True
# <bound method Kernel.raw_input of <ipykernel.ipkernel.IPythonKernel object at 0x7f905e314a30>>
#  83%|████████▎ | 53/64 [02:34<00:24,  2.24s/it]/ssd2/liuyixin04/workspace/logs/benchmark-paddle/train_log/simple_24475_False
# <bound method Kernel.raw_input of <ipykernel.ipkernel.IPythonKernel object at 0x7f905e314a30>>
#  84%|████████▍ | 54/64 [02:35<00:20,  2.02s/it]/ssd2/liuyixin04/workspace/logs/benchmark-paddle/train_log/simple_adversary_30844_True
# <bound method Kernel.raw_input of <ipykernel.ipkernel.IPythonKernel object at 0x7f905e314a30>>
#  86%|████████▌ | 55/64 [02:36<00:15,  1.75s/it]/ssd2/liuyixin04/workspace/logs/benchmark-paddle/train_log/simple_20135_True
# <bound method Kernel.raw_input of <ipykernel.ipkernel.IPythonKernel object at 0x7f905e314a30>>
#  88%|████████▊ | 56/64 [02:38<00:12,  1.60s/it]/ssd2/liuyixin04/workspace/logs/benchmark-paddle/train_log/simple_push_24475_False
# <bound method Kernel.raw_input of <ipykernel.ipkernel.IPythonKernel object at 0x7f905e314a30>>
#  89%|████████▉ | 57/64 [02:43<00:19,  2.77s/it]/ssd2/liuyixin04/workspace/logs/benchmark-paddle/train_log/simple_spread_18326_True
# <bound method Kernel.raw_input of <ipykernel.ipkernel.IPythonKernel object at 0x7f905e314a30>>
#  91%|█████████ | 58/64 [02:49<00:21,  3.62s/it]/ssd2/liuyixin04/workspace/logs/benchmark-paddle/train_log/simple_tag_24475_True
# <bound method Kernel.raw_input of <ipykernel.ipkernel.IPythonKernel object at 0x7f905e314a30>>
#  92%|█████████▏| 59/64 [02:55<00:21,  4.29s/it]/ssd2/liuyixin04/workspace/logs/benchmark-paddle/train_log/simple_tag_20135_True
# <bound method Kernel.raw_input of <ipykernel.ipkernel.IPythonKernel object at 0x7f905e314a30>>
#  94%|█████████▍| 60/64 [03:00<00:18,  4.69s/it]/ssd2/liuyixin04/workspace/logs/benchmark-paddle/train_log/simple_tag_24475_False
# <bound method Kernel.raw_input of <ipykernel.ipkernel.IPythonKernel object at 0x7f905e314a30>>
#  95%|█████████▌| 61/64 [03:02<00:11,  3.72s/it]/ssd2/liuyixin04/workspace/logs/benchmark-paddle/train_log/simple_adversary_18326_False
# <bound method Kernel.raw_input of <ipykernel.ipkernel.IPythonKernel object at 0x7f905e314a30>>
#  97%|█████████▋| 62/64 [03:07<00:08,  4.16s/it]/ssd2/liuyixin04/workspace/logs/benchmark-paddle/train_log/simple_spread_24475_False
# <bound method Kernel.raw_input of <ipykernel.ipkernel.IPythonKernel object at 0x7f905e314a30>>
#  98%|█████████▊| 63/64 [03:13<00:04,  4.67s/it]/ssd2/liuyixin04/workspace/logs/benchmark-paddle/train_log/simple_tag_30844_True
# <bound method Kernel.raw_input of <ipykernel.ipkernel.IPythonKernel object at 0x7f905e314a30>>
# 100%|██████████| 64/64 [03:14<00:00,  3.04s/it]/ssd2/liuyixin04/workspace/logs/benchmark-paddle/train_log/simple_push_30844_False
#
# ['/ssd2/liuyixin04/workspace/logs/tmp/paddle-tmp-1650000382.5837822/MADDPG-continous/simple_adversary/20135_True.csv', '/ssd2/liuyixin04/workspace/logs/tmp/paddle-tmp-1650000382.5837822/MADDPG-continous/simple_adversary/18326_True.csv', '/ssd2/liuyixin04/workspace/logs/tmp/paddle-tmp-1650000382.5837822/MADDPG-continous/simple_adversary/30844_True.csv', '/ssd2/liuyixin04/workspace/logs/tmp/paddle-tmp-1650000382.5837822/MADDPG-continous/simple_adversary/24475_True.csv', '/ssd2/liuyixin04/workspace/logs/tmp/paddle-tmp-1650000382.5837822/MADDPG-continous/simple/20135_True.csv', '/ssd2/liuyixin04/workspace/logs/tmp/paddle-tmp-1650000382.5837822/MADDPG-continous/simple/18326_True.csv', '/ssd2/liuyixin04/workspace/logs/tmp/paddle-tmp-1650000382.5837822/MADDPG-continous/simple/30844_True.csv', '/ssd2/liuyixin04/workspace/logs/tmp/paddle-tmp-1650000382.5837822/MADDPG-continous/simple/24475_True.csv', '/ssd2/liuyixin04/workspace/logs/tmp/paddle-tmp-1650000382.5837822/MADDPG-continous/simple_tag/20135_True.csv', '/ssd2/liuyixin04/workspace/logs/tmp/paddle-tmp-1650000382.5837822/MADDPG-continous/simple_tag/18326_True.csv', '/ssd2/liuyixin04/workspace/logs/tmp/paddle-tmp-1650000382.5837822/MADDPG-continous/simple_tag/30844_True.csv', '/ssd2/liuyixin04/workspace/logs/tmp/paddle-tmp-1650000382.5837822/MADDPG-continous/simple_tag/24475_True.csv', '/ssd2/liuyixin04/workspace/logs/tmp/paddle-tmp-1650000382.5837822/MADDPG-continous/simple_world_comm/20135_True.csv', '/ssd2/liuyixin04/workspace/logs/tmp/paddle-tmp-1650000382.5837822/MADDPG-continous/simple_world_comm/18326_True.csv', '/ssd2/liuyixin04/workspace/logs/tmp/paddle-tmp-1650000382.5837822/MADDPG-continous/simple_world_comm/30844_True.csv', '/ssd2/liuyixin04/workspace/logs/tmp/paddle-tmp-1650000382.5837822/MADDPG-continous/simple_world_comm/24475_True.csv', '/ssd2/liuyixin04/workspace/logs/tmp/paddle-tmp-1650000382.5837822/MADDPG-continous/simple_spread/20135_True.csv', '/ssd2/liuyixin04/workspace/logs/tmp/paddle-tmp-1650000382.5837822/MADDPG-continous/simple_spread/18326_True.csv', '/ssd2/liuyixin04/workspace/logs/tmp/paddle-tmp-1650000382.5837822/MADDPG-continous/simple_spread/30844_True.csv', '/ssd2/liuyixin04/workspace/logs/tmp/paddle-tmp-1650000382.5837822/MADDPG-continous/simple_spread/24475_True.csv', '/ssd2/liuyixin04/workspace/logs/tmp/paddle-tmp-1650000382.5837822/MADDPG-continous/simple_speaker_listener/20135_True.csv', '/ssd2/liuyixin04/workspace/logs/tmp/paddle-tmp-1650000382.5837822/MADDPG-continous/simple_speaker_listener/18326_True.csv', '/ssd2/liuyixin04/workspace/logs/tmp/paddle-tmp-1650000382.5837822/MADDPG-continous/simple_speaker_listener/30844_True.csv', '/ssd2/liuyixin04/workspace/logs/tmp/paddle-tmp-1650000382.5837822/MADDPG-continous/simple_speaker_listener/24475_True.csv', '/ssd2/liuyixin04/workspace/logs/tmp/paddle-tmp-1650000382.5837822/MADDPG-continous/simple_push/20135_True.csv', '/ssd2/liuyixin04/workspace/logs/tmp/paddle-tmp-1650000382.5837822/MADDPG-continous/simple_push/18326_True.csv', '/ssd2/liuyixin04/workspace/logs/tmp/paddle-tmp-1650000382.5837822/MADDPG-continous/simple_push/30844_True.csv', '/ssd2/liuyixin04/workspace/logs/tmp/paddle-tmp-1650000382.5837822/MADDPG-continous/simple_push/24475_True.csv', '/ssd2/liuyixin04/workspace/logs/tmp/paddle-tmp-1650000382.5837822/MADDPG-continous/simple_crypto/20135_True.csv', '/ssd2/liuyixin04/workspace/logs/tmp/paddle-tmp-1650000382.5837822/MADDPG-continous/simple_crypto/18326_True.csv', '/ssd2/liuyixin04/workspace/logs/tmp/paddle-tmp-1650000382.5837822/MADDPG-continous/simple_crypto/30844_True.csv', '/ssd2/liuyixin04/workspace/logs/tmp/paddle-tmp-1650000382.5837822/MADDPG-continous/simple_crypto/24475_True.csv', '/ssd2/liuyixin04/workspace/logs/tmp/paddle-tmp-1650000382.5837822/MADDPG-discrete/simple_adversary/30844_False.csv', '/ssd2/liuyixin04/workspace/logs/tmp/paddle-tmp-1650000382.5837822/MADDPG-discrete/simple_adversary/24475_False.csv', '/ssd2/liuyixin04/workspace/logs/tmp/paddle-tmp-1650000382.5837 ...
# 9
# AxesSubplot(0.672059,0.11;0.227941x0.226471)
# <class 'matplotlib.axes._subplots.AxesSubplot'>
# 9
# [<AxesSubplot:>, <AxesSubplot:>, <AxesSubplot:>, <AxesSubplot:>, <AxesSubplot:>, <AxesSubplot:>, <AxesSubplot:>, <AxesSubplot:>, <AxesSubplot:>]
# -----------env: simple -----------
# 9
# 8
# 0
# MADDPG-continous
# num experients: 4
# window_size: 2
# len steps : 25, values 25
# window_size: 2
# len steps : 25, values 25
# window_size: 2
# len steps : 25, values 25
# window_size: 2
# len steps : 25, values 25
# steps: (25,), mean: (25,), ub: (25,), lb: (25,)
# MADDPG-discrete
# num experients: 4
# window_size: 2
# len steps : 25, values 25
# window_size: 2
# len steps : 25, values 25
# window_size: 2
# len steps : 25, values 25
# window_size: 2
# len steps : 25, values 25
# steps: (25,), mean: (25,), ub: (25,), lb: (25,)
# -----------env: simple_adversary -----------
# 9
# 8
# 1
# MADDPG-continous
# num experients: 4
# window_size: 2
# len steps : 25, values 25
# window_size: 2
# len steps : 25, values 25
# window_size: 2
# len steps : 25, values 25
# window_size: 2
# len steps : 25, values 25
# steps: (25,), mean: (25,), ub: (25,), lb: (25,)
# MADDPG-discrete
# num experients: 4
# window_size: 2
# len steps : 25, values 25
# window_size: 2
# len steps : 25, values 25
# window_size: 2
# len steps : 25, values 25
# window_size: 2
# len steps : 25, values 25
# steps: (25,), mean: (25,), ub: (25,), lb: (25,)
# -----------env: simple_crypto -----------
# 9
# 8
# 2
# MADDPG-continous
# num experients: 4
# window_size: 2
# len steps : 25, values 25
# window_size: 2
# len steps : 25, values 25
# window_size: 2
# len steps : 25, values 25
# window_size: 2
# len steps : 25, values 25
# steps: (25,), mean: (25,), ub: (25,), lb: (25,)
# MADDPG-discrete
# num experients: 4
# window_size: 2
# len steps : 25, values 25
# window_size: 2
# len steps : 25, values 25
# window_size: 2
# len steps : 25, values 25
# window_size: 2
# len steps : 25, values 25
# steps: (25,), mean: (25,), ub: (25,), lb: (25,)
# -----------env: simple_push -----------
# 9
# 8
# 3
# MADDPG-continous
# num experients: 4
# window_size: 2
# len steps : 25, values 25
# window_size: 2
# len steps : 25, values 25
# window_size: 2
# len steps : 25, values 25
# window_size: 2
# len steps : 25, values 25
# steps: (25,), mean: (25,), ub: (25,), lb: (25,)
# MADDPG-discrete
# num experients: 4
# window_size: 2
# len steps : 25, values 25
# window_size: 2
# len steps : 25, values 25
# window_size: 2
# len steps : 25, values 25
# window_size: 2
# len steps : 25, values 25
# steps: (25,), mean: (25,), ub: (25,), lb: (25,)
# -----------env: simple_speaker_listener -----------
# 9
# 8
# 4
# MADDPG-continous
# num experients: 4
# window_size: 2
# len steps : 25, values 25
# window_size: 2
# len steps : 25, values 25
# window_size: 2
# len steps : 25, values 25
# window_size: 2
# len steps : 25, values 25
# steps: (25,), mean: (25,), ub: (25,), lb: (25,)
# MADDPG-discrete
# num experients: 4
# window_size: 2
# len steps : 25, values 25
# window_size: 2
# len steps : 25, values 25
# window_size: 2
# len steps : 25, values 25
# window_size: 2
# len steps : 25, values 25
# steps: (25,), mean: (25,), ub: (25,), lb: (25,)
# -----------env: simple_spread -----------
# 9
# 8
# 5
# MADDPG-continous
# num experients: 4
# window_size: 2
# len steps : 100, values 100
# window_size: 2
# len steps : 100, values 100
# window_size: 2
# len steps : 100, values 100
# window_size: 2
# len steps : 100, values 100
# steps: (100,), mean: (100,), ub: (100,), lb: (100,)
# MADDPG-discrete
# num experients: 4
# window_size: 2
# len steps : 100, values 100
# window_size: 2
# len steps : 100, values 100
# window_size: 2
# len steps : 100, values 100
# window_size: 2
# len steps : 100, values 100
# steps: (100,), mean: (100,), ub: (100,), lb: (100,)
# -----------env: simple_tag -----------
# 9
# 8
# 6
# MADDPG-continous
# num experients: 4
# window_size: 2
# len steps : 100, values 100
# window_size: 2
# len steps : 100, values 100
# window_size: 2
# len steps : 100, values 100
# window_size: 2
# len steps : 100, values 100
# steps: (100,), mean: (100,), ub: (100,), lb: (100,)
# MADDPG-discrete
# num experients: 4
# window_size: 2
# len steps : 100, values 100
# window_size: 2
# len steps : 100, values 100
# window_size: 2
# len steps : 100, values 100
# window_size: 2
# len steps : 100, values 100
# steps: (100,), mean: (100,), ub: (100,), lb: (100,)
# -----------env: simple_world_comm -----------
# 9
# 8
# 7
# MADDPG-continous
# num experients: 4
# window_size: 2
# len steps : 100, values 100
# window_size: 2
# len steps : 100, values 100
# window_size: 2
# len steps : 100, values 100
# window_size: 2
# len steps : 100, values 100
# steps: (100,), mean: (100,), ub: (100,), lb: (100,)
# MADDPG-discrete
# num experients: 4
# window_size: 2
# len steps : 100, values 100
# window_size: 2
# len steps : 100, values 100
# window_size: 2
# len steps : 100, values 100
# window_size: 2
# len steps : 100, values 100
# steps: (100,), mean: (100,), ub: (100,), lb: (100,)
# findfont: Font family ['Times New Roman'] not found. Falling back to DejaVu Sans.
# findfont: Font family ['Times New Roman'] not found. Falling back to DejaVu Sans.
# finished! total time: 2.1862196922302246 s
# 0

# %%
id = "torch"
output = f"/ssd2/liuyixin04/workspace/result-{id}.png"
trian_logdir = f"/ssd2/liuyixin04/workspace/logs/benchmark-{id}/train_log"

from tensorboard.backend.event_processing import event_accumulator
import argparse
import pandas as pd
from tqdm import tqdm
import os 
import time

def mkdir(path):
	folder = os.path.exists(path)
	if not folder:
		os.makedirs(path)

g = os.walk(trian_logdir)
ckpt = []
for path, dir_list, file_names in g:
    # print(path,dir_name,file_names)
    for dir_name in dir_list:
        # print()
        sub_path = os.path.join(path, dir_name)
        ckpt.append(sub_path)
        # break
    # break
    # for f in file_names:
    #     ckpt.append(os.path.join(path,f))

# ckpt=[f for f in ckpt if 'event' in f ]
# in_path='/ssd2/liuyixin04/workspace/PARL/examples/MADDPG/train_log/simple_3013_False'
for in_path in tqdm(ckpt):
    print(input)
    event_data = event_accumulator.EventAccumulator(in_path)  # a python interface for loading Event data
    event_data.Reload()  # synchronously loads all of the data written so far b
    df = pd.DataFrame(event_data.Scalars('mean_episode_reward/episode'))
    df.columns = ['Wall_time', 'Step', 'Value']
    df.to_csv(f'{in_path}/data.csv',index=False)
    print(in_path)
    # break

# create dir
root = f'/ssd2/liuyixin04/workspace/logs/tmp/{id}-tmp-{time.time()}'
mkdir(root)
algs = ['MADDPG-continous','MADDPG-discrete']
for alg in algs:
    mkdir(os.path.join(root,alg))
envs = [
        'simple', 'simple_adversary', 'simple_crypto', 'simple_push',
        'simple_speaker_listener', 'simple_spread', 'simple_tag',
        'simple_world_comm'
    ]
for alg in algs:
    for env in envs:
        path=os.path.join(root,alg)
        mkdir(os.path.join(path,env))
datalist = [f+'/data.csv' for f in ckpt]
flaglist = [d.split('/')[-2] for d in datalist]
flaglist
for i,csv in enumerate(datalist):
    path = root
    if 'True' in flaglist[i]:
        path=os.path.join(path,'MADDPG-continous')
    else:
        path=os.path.join(path,'MADDPG-discrete')
    path = os.path.join(path,'_'.join(flaglist[i].split('_')[:-2]))
    # '/'.join(csv.split('/')[:-1])
    csv_old = os.path.join(path,'data.csv')
    csv_new = csv_old.replace('data','_'.join(flaglist[i].split('_')[-2:]))
    # os.system(f"rm {csv_old}")
    os.system(f'cp {csv} {path}')
    os.system(f"mv {csv_old} {csv_new}")

# os.system(f'rm -r {root}')
# Out:
#   0%|          | 0/64 [00:00<?, ?it/s]<bound method Kernel.raw_input of <ipykernel.ipkernel.IPythonKernel object at 0x7f4d11292a60>>
# 2022-04-17 10:23:06.051481: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/cuda/lib64:/usr/local/cuda/lib::/home/work/cuda-8.0/lib64:/home/work/cuda-8.0/lib:/home/work/cuda-10.2/lib64:/home/work/cuda-10.2/lib
# 2022-04-17 10:23:06.051519: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
#   2%|▏         | 1/64 [00:03<03:15,  3.10s/it]/ssd2/liuyixin04/workspace/logs/benchmark-torch/train_log/simple_speaker_listener_5288_True
# <bound method Kernel.raw_input of <ipykernel.ipkernel.IPythonKernel object at 0x7f4d11292a60>>
#   3%|▎         | 2/64 [00:09<04:54,  4.76s/it]/ssd2/liuyixin04/workspace/logs/benchmark-torch/train_log/simple_tag_21318_True
# <bound method Kernel.raw_input of <ipykernel.ipkernel.IPythonKernel object at 0x7f4d11292a60>>
#   5%|▍         | 3/64 [00:10<03:14,  3.19s/it]/ssd2/liuyixin04/workspace/logs/benchmark-torch/train_log/simple_adversary_17863_True
# <bound method Kernel.raw_input of <ipykernel.ipkernel.IPythonKernel object at 0x7f4d11292a60>>
#   6%|▋         | 4/64 [00:11<02:29,  2.48s/it]/ssd2/liuyixin04/workspace/logs/benchmark-torch/train_log/simple_speaker_listener_8096_False
# <bound method Kernel.raw_input of <ipykernel.ipkernel.IPythonKernel object at 0x7f4d11292a60>>
#   8%|▊         | 5/64 [00:17<03:34,  3.63s/it]/ssd2/liuyixin04/workspace/logs/benchmark-torch/train_log/simple_tag_19352_False
# <bound method Kernel.raw_input of <ipykernel.ipkernel.IPythonKernel object at 0x7f4d11292a60>>
#   9%|▉         | 6/64 [00:18<02:47,  2.88s/it]/ssd2/liuyixin04/workspace/logs/benchmark-torch/train_log/simple_crypto_19352_False
# <bound method Kernel.raw_input of <ipykernel.ipkernel.IPythonKernel object at 0x7f4d11292a60>>
#  11%|█         | 7/64 [00:20<02:12,  2.33s/it]/ssd2/liuyixin04/workspace/logs/benchmark-torch/train_log/simple_speaker_listener_27549_True
# <bound method Kernel.raw_input of <ipykernel.ipkernel.IPythonKernel object at 0x7f4d11292a60>>
#  12%|█▎        | 8/64 [00:21<01:49,  1.96s/it]/ssd2/liuyixin04/workspace/logs/benchmark-torch/train_log/simple_speaker_listener_7931_False
# <bound method Kernel.raw_input of <ipykernel.ipkernel.IPythonKernel object at 0x7f4d11292a60>>
#  14%|█▍        | 9/64 [00:22<01:37,  1.76s/it]/ssd2/liuyixin04/workspace/logs/benchmark-torch/train_log/simple_push_17863_True
# <bound method Kernel.raw_input of <ipykernel.ipkernel.IPythonKernel object at 0x7f4d11292a60>>
#  16%|█▌        | 10/64 [00:23<01:27,  1.62s/it]/ssd2/liuyixin04/workspace/logs/benchmark-torch/train_log/simple_adversary_19352_False
# <bound method Kernel.raw_input of <ipykernel.ipkernel.IPythonKernel object at 0x7f4d11292a60>>
#  17%|█▋        | 11/64 [00:24<01:17,  1.46s/it]/ssd2/liuyixin04/workspace/logs/benchmark-torch/train_log/simple_7931_False
# <bound method Kernel.raw_input of <ipykernel.ipkernel.IPythonKernel object at 0x7f4d11292a60>>
#  19%|█▉        | 12/64 [00:26<01:12,  1.40s/it]/ssd2/liuyixin04/workspace/logs/benchmark-torch/train_log/simple_19352_False
# <bound method Kernel.raw_input of <ipykernel.ipkernel.IPythonKernel object at 0x7f4d11292a60>>
#  20%|██        | 13/64 [00:31<02:09,  2.55s/it]/ssd2/liuyixin04/workspace/logs/benchmark-torch/train_log/simple_spread_21318_True
# <bound method Kernel.raw_input of <ipykernel.ipkernel.IPythonKernel object at 0x7f4d11292a60>>
#  22%|██▏       | 14/64 [00:38<03:10,  3.81s/it]/ssd2/liuyixin04/workspace/logs/benchmark-torch/train_log/simple_world_comm_8096_False
# <bound method Kernel.raw_input of <ipykernel.ipkernel.IPythonKernel object at 0x7f4d11292a60>>
#  23%|██▎       | 15/64 [00:44<03:50,  4.71s/it]/ssd2/liuyixin04/workspace/logs/benchmark-torch/train_log/simple_world_comm_21318_True
# <bound method Kernel.raw_input of <ipykernel.ipkernel.IPythonKernel object at 0x7f4d11292a60>>
#  25%|██▌       | 16/64 [00:50<03:53,  4.86s/it]/ssd2/liuyixin04/workspace/logs/benchmark-torch/train_log/simple_spread_5128_False
# <bound method Kernel.raw_input of <ipykernel.ipkernel.IPythonKernel object at 0x7f4d11292a60>>
#  27%|██▋       | 17/64 [00:56<04:14,  5.42s/it]/ssd2/liuyixin04/workspace/logs/benchmark-torch/train_log/simple_world_comm_24668_True
# <bound method Kernel.raw_input of <ipykernel.ipkernel.IPythonKernel object at 0x7f4d11292a60>>
#  28%|██▊       | 18/64 [00:58<03:12,  4.18s/it]/ssd2/liuyixin04/workspace/logs/benchmark-torch/train_log/simple_speaker_listener_23111_True
# <bound method Kernel.raw_input of <ipykernel.ipkernel.IPythonKernel object at 0x7f4d11292a60>>
#  30%|██▉       | 19/64 [00:59<02:28,  3.30s/it]/ssd2/liuyixin04/workspace/logs/benchmark-torch/train_log/simple_push_8096_False
# <bound method Kernel.raw_input of <ipykernel.ipkernel.IPythonKernel object at 0x7f4d11292a60>>
#  31%|███▏      | 20/64 [01:04<02:52,  3.93s/it]/ssd2/liuyixin04/workspace/logs/benchmark-torch/train_log/simple_spread_8096_False
# <bound method Kernel.raw_input of <ipykernel.ipkernel.IPythonKernel object at 0x7f4d11292a60>>
#  33%|███▎      | 21/64 [01:06<02:15,  3.16s/it]/ssd2/liuyixin04/workspace/logs/benchmark-torch/train_log/simple_adversary_8096_False
# <bound method Kernel.raw_input of <ipykernel.ipkernel.IPythonKernel object at 0x7f4d11292a60>>
#  34%|███▍      | 22/64 [01:11<02:44,  3.93s/it]/ssd2/liuyixin04/workspace/logs/benchmark-torch/train_log/simple_tag_8096_False
# <bound method Kernel.raw_input of <ipykernel.ipkernel.IPythonKernel object at 0x7f4d11292a60>>
#  36%|███▌      | 23/64 [01:13<02:06,  3.09s/it]/ssd2/liuyixin04/workspace/logs/benchmark-torch/train_log/simple_27549_True
# <bound method Kernel.raw_input of <ipykernel.ipkernel.IPythonKernel object at 0x7f4d11292a60>>
#  38%|███▊      | 24/64 [01:19<02:46,  4.16s/it]/ssd2/liuyixin04/workspace/logs/benchmark-torch/train_log/simple_world_comm_4686_True
# <bound method Kernel.raw_input of <ipykernel.ipkernel.IPythonKernel object at 0x7f4d11292a60>>
#  39%|███▉      | 25/64 [01:25<03:00,  4.63s/it]/ssd2/liuyixin04/workspace/logs/benchmark-torch/train_log/simple_tag_29042_True
# <bound method Kernel.raw_input of <ipykernel.ipkernel.IPythonKernel object at 0x7f4d11292a60>>
#  41%|████      | 26/64 [01:26<02:19,  3.67s/it]/ssd2/liuyixin04/workspace/logs/benchmark-torch/train_log/simple_crypto_27549_True
# <bound method Kernel.raw_input of <ipykernel.ipkernel.IPythonKernel object at 0x7f4d11292a60>>
#  42%|████▏     | 27/64 [01:28<01:48,  2.92s/it]/ssd2/liuyixin04/workspace/logs/benchmark-torch/train_log/simple_speaker_listener_5128_False
# <bound method Kernel.raw_input of <ipykernel.ipkernel.IPythonKernel object at 0x7f4d11292a60>>
#  44%|████▍     | 28/64 [01:33<02:11,  3.67s/it]/ssd2/liuyixin04/workspace/logs/benchmark-torch/train_log/simple_spread_7931_False
# <bound method Kernel.raw_input of <ipykernel.ipkernel.IPythonKernel object at 0x7f4d11292a60>>
#  45%|████▌     | 29/64 [01:34<01:42,  2.94s/it]/ssd2/liuyixin04/workspace/logs/benchmark-torch/train_log/simple_push_5288_True
# <bound method Kernel.raw_input of <ipykernel.ipkernel.IPythonKernel object at 0x7f4d11292a60>>
#  47%|████▋     | 30/64 [01:35<01:21,  2.39s/it]/ssd2/liuyixin04/workspace/logs/benchmark-torch/train_log/simple_8096_False
# <bound method Kernel.raw_input of <ipykernel.ipkernel.IPythonKernel object at 0x7f4d11292a60>>
#  48%|████▊     | 31/64 [01:36<01:07,  2.04s/it]/ssd2/liuyixin04/workspace/logs/benchmark-torch/train_log/simple_5128_False
# <bound method Kernel.raw_input of <ipykernel.ipkernel.IPythonKernel object at 0x7f4d11292a60>>
#  50%|█████     | 32/64 [01:38<00:58,  1.81s/it]/ssd2/liuyixin04/workspace/logs/benchmark-torch/train_log/simple_adversary_7931_False
# <bound method Kernel.raw_input of <ipykernel.ipkernel.IPythonKernel object at 0x7f4d11292a60>>
#  52%|█████▏    | 33/64 [01:43<01:26,  2.80s/it]/ssd2/liuyixin04/workspace/logs/benchmark-torch/train_log/simple_spread_29042_True
# <bound method Kernel.raw_input of <ipykernel.ipkernel.IPythonKernel object at 0x7f4d11292a60>>
#  53%|█████▎    | 34/64 [01:44<01:10,  2.36s/it]/ssd2/liuyixin04/workspace/logs/benchmark-torch/train_log/simple_push_23111_True
# <bound method Kernel.raw_input of <ipykernel.ipkernel.IPythonKernel object at 0x7f4d11292a60>>
#  55%|█████▍    | 35/64 [01:46<00:59,  2.04s/it]/ssd2/liuyixin04/workspace/logs/benchmark-torch/train_log/simple_crypto_17863_True
# <bound method Kernel.raw_input of <ipykernel.ipkernel.IPythonKernel object at 0x7f4d11292a60>>
#  56%|█████▋    | 36/64 [01:52<01:36,  3.43s/it]/ssd2/liuyixin04/workspace/logs/benchmark-torch/train_log/simple_world_comm_5128_False
# <bound method Kernel.raw_input of <ipykernel.ipkernel.IPythonKernel object at 0x7f4d11292a60>>
#  58%|█████▊    | 37/64 [01:54<01:15,  2.80s/it]/ssd2/liuyixin04/workspace/logs/benchmark-torch/train_log/simple_adversary_27549_True
# <bound method Kernel.raw_input of <ipykernel.ipkernel.IPythonKernel object at 0x7f4d11292a60>>
#  59%|█████▉    | 38/64 [01:55<01:00,  2.32s/it]/ssd2/liuyixin04/workspace/logs/benchmark-torch/train_log/simple_23111_True
# <bound method Kernel.raw_input of <ipykernel.ipkernel.IPythonKernel object at 0x7f4d11292a60>>
#  61%|██████    | 39/64 [01:56<00:50,  2.03s/it]/ssd2/liuyixin04/workspace/logs/benchmark-torch/train_log/simple_adversary_5128_False
# <bound method Kernel.raw_input of <ipykernel.ipkernel.IPythonKernel object at 0x7f4d11292a60>>
#  62%|██████▎   | 40/64 [01:57<00:42,  1.78s/it]/ssd2/liuyixin04/workspace/logs/benchmark-torch/train_log/simple_speaker_listener_17863_True
# <bound method Kernel.raw_input of <ipykernel.ipkernel.IPythonKernel object at 0x7f4d11292a60>>
#  64%|██████▍   | 41/64 [02:03<01:09,  3.00s/it]/ssd2/liuyixin04/workspace/logs/benchmark-torch/train_log/simple_tag_24668_True
# <bound method Kernel.raw_input of <ipykernel.ipkernel.IPythonKernel object at 0x7f4d11292a60>>
#  66%|██████▌   | 42/64 [02:04<00:54,  2.47s/it]/ssd2/liuyixin04/workspace/logs/benchmark-torch/train_log/simple_push_7931_False
# <bound method Kernel.raw_input of <ipykernel.ipkernel.IPythonKernel object at 0x7f4d11292a60>>
#  67%|██████▋   | 43/64 [02:11<01:18,  3.74s/it]/ssd2/liuyixin04/workspace/logs/benchmark-torch/train_log/simple_world_comm_29042_True
# <bound method Kernel.raw_input of <ipykernel.ipkernel.IPythonKernel object at 0x7f4d11292a60>>
#  69%|██████▉   | 44/64 [02:12<01:00,  3.03s/it]/ssd2/liuyixin04/workspace/logs/benchmark-torch/train_log/simple_crypto_8096_False
# <bound method Kernel.raw_input of <ipykernel.ipkernel.IPythonKernel object at 0x7f4d11292a60>>
#  70%|███████   | 45/64 [02:18<01:12,  3.82s/it]/ssd2/liuyixin04/workspace/logs/benchmark-torch/train_log/simple_tag_5128_False
# <bound method Kernel.raw_input of <ipykernel.ipkernel.IPythonKernel object at 0x7f4d11292a60>>
#  72%|███████▏  | 46/64 [02:19<00:54,  3.05s/it]/ssd2/liuyixin04/workspace/logs/benchmark-torch/train_log/simple_17863_True
# <bound method Kernel.raw_input of <ipykernel.ipkernel.IPythonKernel object at 0x7f4d11292a60>>
#  73%|███████▎  | 47/64 [02:21<00:42,  2.50s/it]/ssd2/liuyixin04/workspace/logs/benchmark-torch/train_log/simple_push_19352_False
# <bound method Kernel.raw_input of <ipykernel.ipkernel.IPythonKernel object at 0x7f4d11292a60>>
#  75%|███████▌  | 48/64 [02:22<00:34,  2.16s/it]/ssd2/liuyixin04/workspace/logs/benchmark-torch/train_log/simple_crypto_7931_False
# <bound method Kernel.raw_input of <ipykernel.ipkernel.IPythonKernel object at 0x7f4d11292a60>>
#  77%|███████▋  | 49/64 [02:23<00:29,  1.94s/it]/ssd2/liuyixin04/workspace/logs/benchmark-torch/train_log/simple_adversary_23111_True
# <bound method Kernel.raw_input of <ipykernel.ipkernel.IPythonKernel object at 0x7f4d11292a60>>
#  78%|███████▊  | 50/64 [02:25<00:24,  1.76s/it]/ssd2/liuyixin04/workspace/logs/benchmark-torch/train_log/simple_crypto_23111_True
# <bound method Kernel.raw_input of <ipykernel.ipkernel.IPythonKernel object at 0x7f4d11292a60>>
#  80%|███████▉  | 51/64 [02:31<00:42,  3.26s/it]/ssd2/liuyixin04/workspace/logs/benchmark-torch/train_log/simple_world_comm_7931_False
# <bound method Kernel.raw_input of <ipykernel.ipkernel.IPythonKernel object at 0x7f4d11292a60>>
#  81%|████████▏ | 52/64 [02:33<00:31,  2.64s/it]/ssd2/liuyixin04/workspace/logs/benchmark-torch/train_log/simple_push_27549_True
# <bound method Kernel.raw_input of <ipykernel.ipkernel.IPythonKernel object at 0x7f4d11292a60>>
#  83%|████████▎ | 53/64 [02:38<00:39,  3.57s/it]/ssd2/liuyixin04/workspace/logs/benchmark-torch/train_log/simple_tag_4686_True
# <bound method Kernel.raw_input of <ipykernel.ipkernel.IPythonKernel object at 0x7f4d11292a60>>
#  84%|████████▍ | 54/64 [02:45<00:45,  4.53s/it]/ssd2/liuyixin04/workspace/logs/benchmark-torch/train_log/simple_world_comm_19352_False
# <bound method Kernel.raw_input of <ipykernel.ipkernel.IPythonKernel object at 0x7f4d11292a60>>
#  86%|████████▌ | 55/64 [02:50<00:42,  4.73s/it]/ssd2/liuyixin04/workspace/logs/benchmark-torch/train_log/simple_spread_24668_True
# <bound method Kernel.raw_input of <ipykernel.ipkernel.IPythonKernel object at 0x7f4d11292a60>>
#  88%|████████▊ | 56/64 [02:52<00:29,  3.73s/it]/ssd2/liuyixin04/workspace/logs/benchmark-torch/train_log/simple_crypto_5288_True
# <bound method Kernel.raw_input of <ipykernel.ipkernel.IPythonKernel object at 0x7f4d11292a60>>
#  89%|████████▉ | 57/64 [02:53<00:21,  3.02s/it]/ssd2/liuyixin04/workspace/logs/benchmark-torch/train_log/simple_crypto_5128_False
# <bound method Kernel.raw_input of <ipykernel.ipkernel.IPythonKernel object at 0x7f4d11292a60>>
#  91%|█████████ | 58/64 [02:58<00:22,  3.70s/it]/ssd2/liuyixin04/workspace/logs/benchmark-torch/train_log/simple_spread_19352_False
# <bound method Kernel.raw_input of <ipykernel.ipkernel.IPythonKernel object at 0x7f4d11292a60>>
#  92%|█████████▏| 59/64 [03:04<00:20,  4.15s/it]/ssd2/liuyixin04/workspace/logs/benchmark-torch/train_log/simple_spread_4686_True
# <bound method Kernel.raw_input of <ipykernel.ipkernel.IPythonKernel object at 0x7f4d11292a60>>
#  94%|█████████▍| 60/64 [03:09<00:18,  4.65s/it]/ssd2/liuyixin04/workspace/logs/benchmark-torch/train_log/simple_tag_7931_False
# <bound method Kernel.raw_input of <ipykernel.ipkernel.IPythonKernel object at 0x7f4d11292a60>>
#  95%|█████████▌| 61/64 [03:11<00:10,  3.59s/it]/ssd2/liuyixin04/workspace/logs/benchmark-torch/train_log/simple_5288_True
# <bound method Kernel.raw_input of <ipykernel.ipkernel.IPythonKernel object at 0x7f4d11292a60>>
#  97%|█████████▋| 62/64 [03:12<00:05,  2.91s/it]/ssd2/liuyixin04/workspace/logs/benchmark-torch/train_log/simple_push_5128_False
# <bound method Kernel.raw_input of <ipykernel.ipkernel.IPythonKernel object at 0x7f4d11292a60>>
#  98%|█████████▊| 63/64 [03:13<00:02,  2.43s/it]/ssd2/liuyixin04/workspace/logs/benchmark-torch/train_log/simple_adversary_5288_True
# <bound method Kernel.raw_input of <ipykernel.ipkernel.IPythonKernel object at 0x7f4d11292a60>>
# 100%|██████████| 64/64 [03:14<00:00,  3.04s/it]/ssd2/liuyixin04/workspace/logs/benchmark-torch/train_log/simple_speaker_listener_19352_False
#
# /ssd2/liuyixin04/miniconda3/envs/py37_paddle/bin/python: can't open file '/ssd2/liuyixin04/workspace/my-repo-yixin/auto-plot-yixin/result-drawing-master/draw_benchmark.py': [Errno 2] No such file or directory
# 512

# %%
print(root)
print(output)
os.system(f'/opt/compiler/gcc-8.2/lib/ld-linux-x86-64.so.2 --library-path /opt/compiler/gcc-8.2/lib:/usr/lib64:/ssd2/liuyixin04/miniconda3/envs/py37_paddle/lib:/home/work/cuda-10.0/lib64/:/home/work/cudnn_v7.4/cuda/lib64/:/ssd2/liuyixin04/.jumbo/lib /ssd2/liuyixin04/miniconda3/envs/py37_paddle/bin/python /ssd2/liuyixin04/workspace/yixin-library/plotting-tool/multi-alg-env-plotting-tool/draw_benchmark.py --path {root} --output {output}')
# Out:
# /ssd2/liuyixin04/workspace/logs/tmp/torch-tmp-1650162380.7104838
# /ssd2/liuyixin04/workspace/result-torch.png
# ['/ssd2/liuyixin04/workspace/logs/tmp/torch-tmp-1650162380.7104838/MADDPG-continous/simple_adversary/17863_True.csv', '/ssd2/liuyixin04/workspace/logs/tmp/torch-tmp-1650162380.7104838/MADDPG-continous/simple_adversary/27549_True.csv', '/ssd2/liuyixin04/workspace/logs/tmp/torch-tmp-1650162380.7104838/MADDPG-continous/simple_adversary/5288_True.csv', '/ssd2/liuyixin04/workspace/logs/tmp/torch-tmp-1650162380.7104838/MADDPG-continous/simple_adversary/23111_True.csv', '/ssd2/liuyixin04/workspace/logs/tmp/torch-tmp-1650162380.7104838/MADDPG-continous/simple/17863_True.csv', '/ssd2/liuyixin04/workspace/logs/tmp/torch-tmp-1650162380.7104838/MADDPG-continous/simple/27549_True.csv', '/ssd2/liuyixin04/workspace/logs/tmp/torch-tmp-1650162380.7104838/MADDPG-continous/simple/5288_True.csv', '/ssd2/liuyixin04/workspace/logs/tmp/torch-tmp-1650162380.7104838/MADDPG-continous/simple/23111_True.csv', '/ssd2/liuyixin04/workspace/logs/tmp/torch-tmp-1650162380.7104838/MADDPG-continous/simple_tag/24668_True.csv', '/ssd2/liuyixin04/workspace/logs/tmp/torch-tmp-1650162380.7104838/MADDPG-continous/simple_tag/21318_True.csv', '/ssd2/liuyixin04/workspace/logs/tmp/torch-tmp-1650162380.7104838/MADDPG-continous/simple_tag/29042_True.csv', '/ssd2/liuyixin04/workspace/logs/tmp/torch-tmp-1650162380.7104838/MADDPG-continous/simple_tag/4686_True.csv', '/ssd2/liuyixin04/workspace/logs/tmp/torch-tmp-1650162380.7104838/MADDPG-continous/simple_world_comm/24668_True.csv', '/ssd2/liuyixin04/workspace/logs/tmp/torch-tmp-1650162380.7104838/MADDPG-continous/simple_world_comm/21318_True.csv', '/ssd2/liuyixin04/workspace/logs/tmp/torch-tmp-1650162380.7104838/MADDPG-continous/simple_world_comm/29042_True.csv', '/ssd2/liuyixin04/workspace/logs/tmp/torch-tmp-1650162380.7104838/MADDPG-continous/simple_world_comm/4686_True.csv', '/ssd2/liuyixin04/workspace/logs/tmp/torch-tmp-1650162380.7104838/MADDPG-continous/simple_spread/24668_True.csv', '/ssd2/liuyixin04/workspace/logs/tmp/torch-tmp-1650162380.7104838/MADDPG-continous/simple_spread/21318_True.csv', '/ssd2/liuyixin04/workspace/logs/tmp/torch-tmp-1650162380.7104838/MADDPG-continous/simple_spread/29042_True.csv', '/ssd2/liuyixin04/workspace/logs/tmp/torch-tmp-1650162380.7104838/MADDPG-continous/simple_spread/4686_True.csv', '/ssd2/liuyixin04/workspace/logs/tmp/torch-tmp-1650162380.7104838/MADDPG-continous/simple_speaker_listener/17863_True.csv', '/ssd2/liuyixin04/workspace/logs/tmp/torch-tmp-1650162380.7104838/MADDPG-continous/simple_speaker_listener/27549_True.csv', '/ssd2/liuyixin04/workspace/logs/tmp/torch-tmp-1650162380.7104838/MADDPG-continous/simple_speaker_listener/5288_True.csv', '/ssd2/liuyixin04/workspace/logs/tmp/torch-tmp-1650162380.7104838/MADDPG-continous/simple_speaker_listener/23111_True.csv', '/ssd2/liuyixin04/workspace/logs/tmp/torch-tmp-1650162380.7104838/MADDPG-continous/simple_push/17863_True.csv', '/ssd2/liuyixin04/workspace/logs/tmp/torch-tmp-1650162380.7104838/MADDPG-continous/simple_push/27549_True.csv', '/ssd2/liuyixin04/workspace/logs/tmp/torch-tmp-1650162380.7104838/MADDPG-continous/simple_push/5288_True.csv', '/ssd2/liuyixin04/workspace/logs/tmp/torch-tmp-1650162380.7104838/MADDPG-continous/simple_push/23111_True.csv', '/ssd2/liuyixin04/workspace/logs/tmp/torch-tmp-1650162380.7104838/MADDPG-continous/simple_crypto/17863_True.csv', '/ssd2/liuyixin04/workspace/logs/tmp/torch-tmp-1650162380.7104838/MADDPG-continous/simple_crypto/27549_True.csv', '/ssd2/liuyixin04/workspace/logs/tmp/torch-tmp-1650162380.7104838/MADDPG-continous/simple_crypto/5288_True.csv', '/ssd2/liuyixin04/workspace/logs/tmp/torch-tmp-1650162380.7104838/MADDPG-continous/simple_crypto/23111_True.csv', '/ssd2/liuyixin04/workspace/logs/tmp/torch-tmp-1650162380.7104838/MADDPG-discrete/simple_adversary/7931_False.csv', '/ssd2/liuyixin04/workspace/logs/tmp/torch-tmp-1650162380.7104838/MADDPG-discrete/simple_adversary/8096_False.csv', '/ssd2/liuyixin04/workspace/logs/tmp/torch-tmp-1650162380.7104838/MADDPG-discrete/simple_adversary/19352_Fa ...
# 9
# AxesSubplot(0.672059,0.11;0.227941x0.226471)
# <class 'matplotlib.axes._subplots.AxesSubplot'>
# 9
# [<AxesSubplot:>, <AxesSubplot:>, <AxesSubplot:>, <AxesSubplot:>, <AxesSubplot:>, <AxesSubplot:>, <AxesSubplot:>, <AxesSubplot:>, <AxesSubplot:>]
# -----------env: simple -----------
# 9
# 8
# 0
# MADDPG-continous
# num experients: 4
# window_size: 2
# len steps : 25, values 25
# window_size: 2
# len steps : 25, values 25
# window_size: 2
# len steps : 25, values 25
# window_size: 2
# len steps : 25, values 25
# steps: (25,), mean: (25,), ub: (25,), lb: (25,)
# MADDPG-discrete
# num experients: 4
# window_size: 2
# len steps : 25, values 25
# window_size: 2
# len steps : 25, values 25
# window_size: 2
# len steps : 25, values 25
# window_size: 2
# len steps : 25, values 25
# steps: (25,), mean: (25,), ub: (25,), lb: (25,)
# -----------env: simple_adversary -----------
# 9
# 8
# 1
# MADDPG-continous
# num experients: 4
# window_size: 2
# len steps : 25, values 25
# window_size: 2
# len steps : 25, values 25
# window_size: 2
# len steps : 25, values 25
# window_size: 2
# len steps : 25, values 25
# steps: (25,), mean: (25,), ub: (25,), lb: (25,)
# MADDPG-discrete
# num experients: 4
# window_size: 2
# len steps : 25, values 25
# window_size: 2
# len steps : 25, values 25
# window_size: 2
# len steps : 25, values 25
# window_size: 2
# len steps : 25, values 25
# steps: (25,), mean: (25,), ub: (25,), lb: (25,)
# -----------env: simple_crypto -----------
# 9
# 8
# 2
# MADDPG-continous
# num experients: 4
# window_size: 2
# len steps : 25, values 25
# window_size: 2
# len steps : 25, values 25
# window_size: 2
# len steps : 25, values 25
# window_size: 2
# len steps : 25, values 25
# steps: (25,), mean: (25,), ub: (25,), lb: (25,)
# MADDPG-discrete
# num experients: 4
# window_size: 2
# len steps : 25, values 25
# window_size: 2
# len steps : 25, values 25
# window_size: 2
# len steps : 25, values 25
# window_size: 2
# len steps : 25, values 25
# steps: (25,), mean: (25,), ub: (25,), lb: (25,)
# -----------env: simple_push -----------
# 9
# 8
# 3
# MADDPG-continous
# num experients: 4
# window_size: 2
# len steps : 25, values 25
# window_size: 2
# len steps : 25, values 25
# window_size: 2
# len steps : 25, values 25
# window_size: 2
# len steps : 25, values 25
# steps: (25,), mean: (25,), ub: (25,), lb: (25,)
# MADDPG-discrete
# num experients: 4
# window_size: 2
# len steps : 25, values 25
# window_size: 2
# len steps : 25, values 25
# window_size: 2
# len steps : 25, values 25
# window_size: 2
# len steps : 25, values 25
# steps: (25,), mean: (25,), ub: (25,), lb: (25,)
# -----------env: simple_speaker_listener -----------
# 9
# 8
# 4
# MADDPG-continous
# num experients: 4
# window_size: 2
# len steps : 25, values 25
# window_size: 2
# len steps : 25, values 25
# window_size: 2
# len steps : 25, values 25
# window_size: 2
# len steps : 25, values 25
# steps: (25,), mean: (25,), ub: (25,), lb: (25,)
# MADDPG-discrete
# num experients: 4
# window_size: 2
# len steps : 25, values 25
# window_size: 2
# len steps : 25, values 25
# window_size: 2
# len steps : 25, values 25
# window_size: 2
# len steps : 25, values 25
# steps: (25,), mean: (25,), ub: (25,), lb: (25,)
# -----------env: simple_spread -----------
# 9
# 8
# 5
# MADDPG-continous
# num experients: 4
# window_size: 2
# len steps : 100, values 100
# window_size: 2
# len steps : 100, values 100
# window_size: 2
# len steps : 100, values 100
# window_size: 2
# len steps : 100, values 100
# steps: (100,), mean: (100,), ub: (100,), lb: (100,)
# MADDPG-discrete
# num experients: 4
# window_size: 2
# len steps : 100, values 100
# window_size: 2
# len steps : 100, values 100
# window_size: 2
# len steps : 100, values 100
# window_size: 2
# len steps : 100, values 100
# steps: (100,), mean: (100,), ub: (100,), lb: (100,)
# -----------env: simple_tag -----------
# 9
# 8
# 6
# MADDPG-continous
# num experients: 4
# window_size: 2
# len steps : 100, values 100
# window_size: 2
# len steps : 100, values 100
# window_size: 2
# len steps : 100, values 100
# window_size: 2
# len steps : 100, values 100
# steps: (100,), mean: (100,), ub: (100,), lb: (100,)
# MADDPG-discrete
# num experients: 4
# window_size: 2
# len steps : 100, values 100
# window_size: 2
# len steps : 100, values 100
# window_size: 2
# len steps : 100, values 100
# window_size: 2
# len steps : 100, values 100
# steps: (100,), mean: (100,), ub: (100,), lb: (100,)
# -----------env: simple_world_comm -----------
# 9
# 8
# 7
# MADDPG-continous
# num experients: 4
# window_size: 2
# len steps : 100, values 100
# window_size: 2
# len steps : 100, values 100
# window_size: 2
# len steps : 100, values 100
# window_size: 2
# len steps : 100, values 100
# steps: (100,), mean: (100,), ub: (100,), lb: (100,)
# MADDPG-discrete
# num experients: 4
# window_size: 2
# len steps : 100, values 100
# window_size: 2
# len steps : 100, values 100
# window_size: 2
# len steps : 100, values 100
# window_size: 2
# len steps : 100, values 100
# steps: (100,), mean: (100,), ub: (100,), lb: (100,)
# findfont: Font family ['Times New Roman'] not found. Falling back to DejaVu Sans.
# findfont: Font family ['Times New Roman'] not found. Falling back to DejaVu Sans.
# finished! total time: 2.1905975341796875 s
# 0

# %%
os.system(f'/opt/compiler/gcc-8.2/lib/ld-linux-x86-64.so.2 --library-path /opt/compiler/gcc-8.2/lib:/usr/lib64:/ssd2/liuyixin04/miniconda3/envs/py37_paddle/lib:/home/work/cuda-10.0/lib64/:/home/work/cudnn_v7.4/cuda/lib64/:/ssd2/liuyixin04/.jumbo/lib /ssd2/liuyixin04/miniconda3/envs/py37_paddle/bin/python /ssd2/liuyixin04/workspace/my-repo-yixin/auto-plot-yixin/result-drawing-master/draw_benchmark.py --path /ssd2/liuyixin04/workspace/logs/tmp/paddle-tmp-1650000382.5837822 --output /ssd2/liuyixin04/workspace/result-paddle.png')
os.system(f'/opt/compiler/gcc-8.2/lib/ld-linux-x86-64.so.2 --library-path /opt/compiler/gcc-8.2/lib:/usr/lib64:/ssd2/liuyixin04/miniconda3/envs/py37_paddle/lib:/home/work/cuda-10.0/lib64/:/home/work/cudnn_v7.4/cuda/lib64/:/ssd2/liuyixin04/.jumbo/lib /ssd2/liuyixin04/miniconda3/envs/py37_paddle/bin/python /ssd2/liuyixin04/workspace/my-repo-yixin/auto-plot-yixin/result-drawing-master/draw_benchmark.py --path /ssd2/liuyixin04/workspace/logs/tmp/torch-tmp-1650000583.2686312 --output /ssd2/liuyixin04/workspace/result-torch.png')
# Out:
# liuyixin04/workspace/logs/tmp/paddle-tmp-1650000382.5837822/MADDPG-discrete/simple/18326_False.csv', '/ssd2/liuyixin04/workspace/logs/tmp/paddle-tmp-1650000382.5837822/MADDPG-discrete/simple/20135_False.csv', '/ssd2/liuyixin04/workspace/logs/tmp/paddle-tmp-1650000382.5837822/MADDPG-discrete/simple_tag/30844_False.csv', '/ssd2/liuyixin04/workspace/logs/tmp/paddle-tmp-1650000382.5837822/MADDPG-discrete/simple_tag/24475_False.csv', '/ssd2/liuyixin04/workspace/logs/tmp/paddle-tmp-1650000382.5837822/MADDPG-discrete/simple_tag/18326_False.csv', '/ssd2/liuyixin04/workspace/logs/tmp/paddle-tmp-1650000382.5837822/MADDPG-discrete/simple_tag/20135_False.csv', '/ssd2/liuyixin04/workspace/logs/tmp/paddle-tmp-1650000382.5837822/MADDPG-discrete/simple_world_comm/30844_False.csv', '/ssd2/liuyixin04/workspace/logs/tmp/paddle-tmp-1650000382.5837822/MADDPG-discrete/simple_world_comm/24475_False.csv', '/ssd2/liuyixin04/workspace/logs/tmp/paddle-tmp-1650000382.5837822/MADDPG-discrete/simple_world_comm/18326_False.csv', '/ssd2/liuyixin04/workspace/logs/tmp/paddle-tmp-1650000382.5837822/MADDPG-discrete/simple_world_comm/20135_False.csv', '/ssd2/liuyixin04/workspace/logs/tmp/paddle-tmp-1650000382.5837822/MADDPG-discrete/simple_spread/30844_False.csv', '/ssd2/liuyixin04/workspace/logs/tmp/paddle-tmp-1650000382.5837822/MADDPG-discrete/simple_spread/24475_False.csv', '/ssd2/liuyixin04/workspace/logs/tmp/paddle-tmp-1650000382.5837822/MADDPG-discrete/simple_spread/18326_False.csv', '/ssd2/liuyixin04/workspace/logs/tmp/paddle-tmp-1650000382.5837822/MADDPG-discrete/simple_spread/20135_False.csv', '/ssd2/liuyixin04/workspace/logs/tmp/paddle-tmp-1650000382.5837822/MADDPG-discrete/simple_speaker_listener/30844_False.csv', '/ssd2/liuyixin04/workspace/logs/tmp/paddle-tmp-1650000382.5837822/MADDPG-discrete/simple_speaker_listener/24475_False.csv', '/ssd2/liuyixin04/workspace/logs/tmp/paddle-tmp-1650000382.5837822/MADDPG-discrete/simple_speaker_listener/18326_False.csv', '/ssd2/liuyixin04/workspace/logs/tmp/paddle-tmp-1650000382.5837822/MADDPG-discrete/simple_speaker_listener/20135_False.csv', '/ssd2/liuyixin04/workspace/logs/tmp/paddle-tmp-1650000382.5837822/MADDPG-discrete/simple_push/30844_False.csv', '/ssd2/liuyixin04/workspace/logs/tmp/paddle-tmp-1650000382.5837822/MADDPG-discrete/simple_push/24475_False.csv', '/ssd2/liuyixin04/workspace/logs/tmp/paddle-tmp-1650000382.5837822/MADDPG-discrete/simple_push/18326_False.csv', '/ssd2/liuyixin04/workspace/logs/tmp/paddle-tmp-1650000382.5837822/MADDPG-discrete/simple_push/20135_False.csv', '/ssd2/liuyixin04/workspace/logs/tmp/paddle-tmp-1650000382.5837822/MADDPG-discrete/simple_crypto/30844_False.csv', '/ssd2/liuyixin04/workspace/logs/tmp/paddle-tmp-1650000382.5837822/MADDPG-discrete/simple_crypto/24475_False.csv', '/ssd2/liuyixin04/workspace/logs/tmp/paddle-tmp-1650000382.5837822/MADDPG-discrete/simple_crypto/18326_False.csv', '/ssd2/liuyixin04/workspace/logs/tmp/paddle-tmp-1650000382.5837822/MADDPG-discrete/simple_crypto/20135_False.csv']
# 9
# AxesSubplot(0.672059,0.11;0.227941x0.226471)
# <class 'matplotlib.axes._subplots.AxesSubplot'>
# 9
# [<AxesSubplot:>, <AxesSubplot:>, <AxesSubplot:>, <AxesSubplot:>, <AxesSubplot:>, <AxesSubplot:>, <AxesSubplot:>, <AxesSubplot:>, <AxesSubplot:>]
# -----------env: simple -----------
# 9
# 8
# 0
# MADDPG-continous
# num experients: 4
# window_size: 2
# len steps : 25, values 25
# window_size: 2
# len steps : 25, values 25
# window_size: 2
# len steps : 25, values 25
# window_size: 2
# len steps : 25, values 25
# steps: (25,), mean: (25,), ub: (25,), lb: (25,)
# MADDPG-discrete
# num experients: 4
# window_size: 2
# len steps : 25, values 25
# window_size: 2
# len steps : 25, values 25
# window_size: 2
# len steps : 25, values 25
# window_size: 2
# len steps : 25, values 25
# steps: (25,), mean: (25,), ub: (25,), lb: (25,)
# -----------env: simple_adversary -----------
# 9
# 8
# 1
# MADDPG-continous
# num experients: 4
# window_size: 2
# len steps : 25, values 25
# window_size: 2
# len steps : 25, values 25
# window_size: 2
# len steps : 25, values 25
# window_size: 2
# len steps : 25, values 25
# steps: (25,), mean: (25,), ub: (25,), lb: (25,)
# MADDPG-discrete
# num experients: 4
# window_size: 2
# len steps : 25, values 25
# window_size: 2
# len steps : 25, values 25
# window_size: 2
# len steps : 25, values 25
# window_size: 2
# len steps : 25, values 25
# steps: (25,), mean: (25,), ub: (25,), lb: (25,)
# -----------env: simple_crypto -----------
# 9
# 8
# 2
# MADDPG-continous
# num experients: 4
# window_size: 2
# len steps : 25, values 25
# window_size: 2
# len steps : 25, values 25
# window_size: 2
# len steps : 25, values 25
# window_size: 2
# len steps : 25, values 25
# steps: (25,), mean: (25,), ub: (25,), lb: (25,)
# MADDPG-discrete
# num experients: 4
# window_size: 2
# len steps : 25, values 25
# window_size: 2
# len steps : 25, values 25
# window_size: 2
# len steps : 25, values 25
# window_size: 2
# len steps : 25, values 25
# steps: (25,), mean: (25,), ub: (25,), lb: (25,)
# -----------env: simple_push -----------
# 9
# 8
# 3
# MADDPG-continous
# num experients: 4
# window_size: 2
# len steps : 25, values 25
# window_size: 2
# len steps : 25, values 25
# window_size: 2
# len steps : 25, values 25
# window_size: 2
# len steps : 25, values 25
# steps: (25,), mean: (25,), ub: (25,), lb: (25,)
# MADDPG-discrete
# num experients: 4
# window_size: 2
# len steps : 25, values 25
# window_size: 2
# len steps : 25, values 25
# window_size: 2
# len steps : 25, values 25
# window_size: 2
# len steps : 25, values 25
# steps: (25,), mean: (25,), ub: (25,), lb: (25,)
# -----------env: simple_speaker_listener -----------
# 9
# 8
# 4
# MADDPG-continous
# num experients: 4
# window_size: 2
# len steps : 25, values 25
# window_size: 2
# len steps : 25, values 25
# window_size: 2
# len steps : 25, values 25
# window_size: 2
# len steps : 25, values 25
# steps: (25,), mean: (25,), ub: (25,), lb: (25,)
# MADDPG-discrete
# num experients: 4
# window_size: 2
# len steps : 25, values 25
# window_size: 2
# len steps : 25, values 25
# window_size: 2
# len steps : 25, values 25
# window_size: 2
# len steps : 25, values 25
# steps: (25,), mean: (25,), ub: (25,), lb: (25,)
# -----------env: simple_spread -----------
# 9
# 8
# 5
# MADDPG-continous
# num experients: 4
# window_size: 2
# len steps : 100, values 100
# window_size: 2
# len steps : 100, values 100
# window_size: 2
# len steps : 100, values 100
# window_size: 2
# len steps : 100, values 100
# steps: (100,), mean: (100,), ub: (100,), lb: (100,)
# MADDPG-discrete
# num experients: 4
# window_size: 2
# len steps : 100, values 100
# window_size: 2
# len steps : 100, values 100
# window_size: 2
# len steps : 100, values 100
# window_size: 2
# len steps : 100, values 100
# steps: (100,), mean: (100,), ub: (100,), lb: (100,)
# -----------env: simple_tag -----------
# 9
# 8
# 6
# MADDPG-continous
# num experients: 4
# window_size: 2
# len steps : 100, values 100
# window_size: 2
# len steps : 100, values 100
# window_size: 2
# len steps : 100, values 100
# window_size: 2
# len steps : 100, values 100
# steps: (100,), mean: (100,), ub: (100,), lb: (100,)
# MADDPG-discrete
# num experients: 4
# window_size: 2
# len steps : 100, values 100
# window_size: 2
# len steps : 100, values 100
# window_size: 2
# len steps : 100, values 100
# window_size: 2
# len steps : 100, values 100
# steps: (100,), mean: (100,), ub: (100,), lb: (100,)
# -----------env: simple_world_comm -----------
# 9
# 8
# 7
# MADDPG-continous
# num experients: 4
# window_size: 2
# len steps : 100, values 100
# window_size: 2
# len steps : 100, values 100
# window_size: 2
# len steps : 100, values 100
# window_size: 2
# len steps : 100, values 100
# steps: (100,), mean: (100,), ub: (100,), lb: (100,)
# MADDPG-discrete
# num experients: 4
# window_size: 2
# len steps : 100, values 100
# window_size: 2
# len steps : 100, values 100
# window_size: 2
# len steps : 100, values 100
# window_size: 2
# len steps : 100, values 100
# steps: (100,), mean: (100,), ub: (100,), lb: (100,)
# findfont: Font family ['Times New Roman'] not found. Falling back to DejaVu Sans.
# findfont: Font family ['Times New Roman'] not found. Falling back to DejaVu Sans.
# finished! total time: 2.193120241165161 s
# ['/ssd2/liuyixin04/workspace/logs/tmp/torch-tmp-1650000583.2686312/MADDPG-continous/simple_adversary/8096_True.csv', '/ssd2/liuyixin04/workspace/logs/tmp/torch-tmp-1650000583.2686312/MADDPG-continous/simple_adversary/5128_True.csv', '/ssd2/liuyixin04/workspace/logs/tmp/torch-tmp-1650000583.2686312/MADDPG-continous/simple_adversary/19352_True.csv', '/ssd2/liuyixin04/workspace/logs/tmp/torch-tmp-1650000583.2686312/MADDPG-continous/simple_adversary/7931_True.csv', '/ssd2/liuyixin04/workspace/logs/tmp/torch-tmp-1650000583.2686312/MADDPG-continous/simple/8096_True.csv', '/ssd2/liuyixin04/workspace/logs/tmp/torch-tmp-1650000583.2686312/MADDPG-continous/simple/5128_True.csv', '/ssd2/liuyixin04/workspace/logs/tmp/torch-tmp-1650000583.2686312/MADDPG-continous/simple/19352_True.csv', '/ssd2/liuyixin04/workspace/logs/tmp/torch-tmp-1650000583.2686312/MADDPG-continous/simple/7931_True.csv', '/ssd2/liuyixin04/workspace/logs/tmp/torch-tmp-1650000583.2686312/MADDPG-continous/simple_tag/8096_True.csv', '/ssd2/liuyixin04/workspace/logs/tmp/torch-tmp-1650000583.2686312/MADDPG-continous/simple_tag/5128_True.csv', '/ssd2/liuyixin04/workspace/logs/tmp/torch-tmp-1650000583.2686312/MADDPG-continous/simple_tag/19352_True.csv', '/ssd2/liuyixin04/workspace/logs/tmp/torch-tmp-1650000583.2686312/MADDPG-continous/simple_tag/7931_True.csv', '/ssd2/liuyixin04/workspace/logs/tmp/torch-tmp-1650000583.2686312/MADDPG-continous/simple_world_comm/8096_True.csv', '/ssd2/liuyixin04/workspace/logs/tmp/torch-tmp-1650000583.2686312/MADDPG-continous/simple_world_comm/5128_True.csv', '/ssd2/liuyixin04/workspace/logs/tmp/torch-tmp-1650000583.2686312/MADDPG-continous/simple_world_comm/19352_True.csv', '/ssd2/liuyixin04/workspace/logs/tmp/torch-tmp-1650000583.2686312/MADDPG-continous/simple_world_comm/7931_True.csv', '/ssd2/liuyixin04/workspace/logs/tmp/torch-tmp-1650000583.2686312/MADDPG-continous/simple_spread/8096_True.csv', '/ssd2/liuyixin04/workspace/logs/tmp/torch-tmp-1650000583.2686312/MADDPG-continous/simple_spread/5128_True.csv', '/ssd2/liuyixin04/workspace/logs/tmp/torch-tmp-1650000583.2686312/MADDPG-continous/simple_spread/19352_True.csv', '/ssd2/liuyixin04/workspace/logs/tmp/torch-tmp-1650000583.2686312/MADDPG-continous/simple_spread/7931_True.csv', '/ssd2/liuyixin04/workspace/logs/tmp/torch-tmp-1650000583.2686312/MADDPG-continous/simple_speaker_listener/8096_True.csv', '/ssd2/liuyixin04/workspace/logs/tmp/torch-tmp-1650000583.2686312/MADDPG-continous/simple_speaker_listener/5128_True.csv', '/ssd2/liuyixin04/workspace/logs/tmp/torch-tmp-1650000583.2686312/MADDPG-continous/simple_speaker_listener/19352_True.csv', '/ssd2/liuyixin04/workspace/logs/tmp/torch-tmp-1650000583.2686312/MADDPG-continous/simple_speaker_listener/7931_True.csv', '/ssd2/liuyixin04/workspace/logs/tmp/torch-tmp-1650000583.2686312/MADDPG-continous/simple_push/8096_True.csv', '/ssd2/liuyixin04/workspace/logs/tmp/torch-tmp-1650000583.2686312/MADDPG-continous/simple_push/5128_True.csv', '/ssd2/liuyixin04/workspace/logs/tmp/torch-tmp-1650000583.2686312/MADDPG-continous/simple_push/19352_True.csv', '/ssd2/liuyixin04/workspace/logs/tmp/torch-tmp-1650000583.2686312/MADDPG-continous/simple_push/7931_True.csv', '/ssd2/liuyixin04/workspace/logs/tmp/torch-tmp-1650000583.2686312/MADDPG-continous/simple_crypto/8096_True.csv', '/ssd2/liuyixin04/workspace/logs/tmp/torch-tmp-1650000583.2686312/MADDPG-continous/simple_crypto/5128_True.csv', '/ssd2/liuyixin04/workspace/logs/tmp/torch-tmp-1650000583.2686312/MADDPG-continous/simple_crypto/19352_True.csv', '/ssd2/liuyixin04/workspace/logs/tmp/torch-tmp-1650000583.2686312/MADDPG-continous/simple_crypto/7931_True.csv', '/ssd2/liuyixin04/workspace/logs/tmp/torch-tmp-1650000583.2686312/MADDPG-discrete/simple_adversary/7931_False.csv', '/ssd2/liuyixin04/workspace/logs/tmp/torch-tmp-1650000583.2686312/MADDPG-discrete/simple_adversary/8096_False.csv', '/ssd2/liuyixin04/workspace/logs/tmp/torch-tmp-1650000583.2686312/MADDPG-discrete/simple_adversary/19352_False.csv', '/ssd2 ...
# 9
# AxesSubplot(0.672059,0.11;0.227941x0.226471)
# <class 'matplotlib.axes._subplots.AxesSubplot'>
# 9
# [<AxesSubplot:>, <AxesSubplot:>, <AxesSubplot:>, <AxesSubplot:>, <AxesSubplot:>, <AxesSubplot:>, <AxesSubplot:>, <AxesSubplot:>, <AxesSubplot:>]
# -----------env: simple -----------
# 9
# 8
# 0
# MADDPG-continous
# num experients: 4
# window_size: 2
# len steps : 25, values 25
# window_size: 2
# len steps : 25, values 25
# window_size: 2
# len steps : 25, values 25
# window_size: 2
# len steps : 25, values 25
# steps: (25,), mean: (25,), ub: (25,), lb: (25,)
# MADDPG-discrete
# num experients: 4
# window_size: 2
# len steps : 25, values 25
# window_size: 2
# len steps : 25, values 25
# window_size: 2
# len steps : 25, values 25
# window_size: 2
# len steps : 25, values 25
# steps: (25,), mean: (25,), ub: (25,), lb: (25,)
# -----------env: simple_adversary -----------
# 9
# 8
# 1
# MADDPG-continous
# num experients: 4
# window_size: 2
# len steps : 25, values 25
# window_size: 2
# len steps : 25, values 25
# window_size: 2
# len steps : 25, values 25
# window_size: 2
# len steps : 25, values 25
# steps: (25,), mean: (25,), ub: (25,), lb: (25,)
# MADDPG-discrete
# num experients: 4
# window_size: 2
# len steps : 25, values 25
# window_size: 2
# len steps : 25, values 25
# window_size: 2
# len steps : 25, values 25
# window_size: 2
# len steps : 25, values 25
# steps: (25,), mean: (25,), ub: (25,), lb: (25,)
# -----------env: simple_crypto -----------
# 9
# 8
# 2
# MADDPG-continous
# num experients: 4
# window_size: 2
# len steps : 25, values 25
# window_size: 2
# len steps : 25, values 25
# window_size: 2
# len steps : 25, values 25
# window_size: 2
# len steps : 25, values 25
# steps: (25,), mean: (25,), ub: (25,), lb: (25,)
# MADDPG-discrete
# num experients: 4
# window_size: 2
# len steps : 25, values 25
# window_size: 2
# len steps : 25, values 25
# window_size: 2
# len steps : 25, values 25
# window_size: 2
# len steps : 25, values 25
# steps: (25,), mean: (25,), ub: (25,), lb: (25,)
# -----------env: simple_push -----------
# 9
# 8
# 3
# MADDPG-continous
# num experients: 4
# window_size: 2
# len steps : 25, values 25
# window_size: 2
# len steps : 25, values 25
# window_size: 2
# len steps : 25, values 25
# window_size: 2
# len steps : 25, values 25
# steps: (25,), mean: (25,), ub: (25,), lb: (25,)
# MADDPG-discrete
# num experients: 4
# window_size: 2
# len steps : 25, values 25
# window_size: 2
# len steps : 25, values 25
# window_size: 2
# len steps : 25, values 25
# window_size: 2
# len steps : 25, values 25
# steps: (25,), mean: (25,), ub: (25,), lb: (25,)
# -----------env: simple_speaker_listener -----------
# 9
# 8
# 4
# MADDPG-continous
# num experients: 4
# window_size: 2
# len steps : 25, values 25
# window_size: 2
# len steps : 25, values 25
# window_size: 2
# len steps : 25, values 25
# window_size: 2
# len steps : 25, values 25
# steps: (25,), mean: (25,), ub: (25,), lb: (25,)
# MADDPG-discrete
# num experients: 4
# window_size: 2
# len steps : 25, values 25
# window_size: 2
# len steps : 25, values 25
# window_size: 2
# len steps : 25, values 25
# window_size: 2
# len steps : 25, values 25
# steps: (25,), mean: (25,), ub: (25,), lb: (25,)
# -----------env: simple_spread -----------
# 9
# 8
# 5
# MADDPG-continous
# num experients: 4
# window_size: 2
# len steps : 100, values 100
# window_size: 2
# len steps : 100, values 100
# window_size: 2
# len steps : 100, values 100
# window_size: 2
# len steps : 100, values 100
# steps: (100,), mean: (100,), ub: (100,), lb: (100,)
# MADDPG-discrete
# num experients: 4
# window_size: 2
# len steps : 100, values 100
# window_size: 2
# len steps : 100, values 100
# window_size: 2
# len steps : 100, values 100
# window_size: 2
# len steps : 100, values 100
# steps: (100,), mean: (100,), ub: (100,), lb: (100,)
# -----------env: simple_tag -----------
# 9
# 8
# 6
# MADDPG-continous
# num experients: 4
# window_size: 2
# len steps : 100, values 100
# window_size: 2
# len steps : 100, values 100
# window_size: 2
# len steps : 100, values 100
# window_size: 2
# len steps : 100, values 100
# steps: (100,), mean: (100,), ub: (100,), lb: (100,)
# MADDPG-discrete
# num experients: 4
# window_size: 2
# len steps : 100, values 100
# window_size: 2
# len steps : 100, values 100
# window_size: 2
# len steps : 100, values 100
# window_size: 2
# len steps : 100, values 100
# steps: (100,), mean: (100,), ub: (100,), lb: (100,)
# -----------env: simple_world_comm -----------
# 9
# 8
# 7
# MADDPG-continous
# num experients: 4
# window_size: 2
# len steps : 100, values 100
# window_size: 2
# len steps : 100, values 100
# window_size: 2
# len steps : 100, values 100
# window_size: 2
# len steps : 100, values 100
# steps: (100,), mean: (100,), ub: (100,), lb: (100,)
# MADDPG-discrete
# num experients: 4
# window_size: 2
# len steps : 100, values 100
# window_size: 2
# len steps : 100, values 100
# window_size: 2
# len steps : 100, values 100
# window_size: 2
# len steps : 100, values 100
# steps: (100,), mean: (100,), ub: (100,), lb: (100,)
# findfont: Font family ['Times New Roman'] not found. Falling back to DejaVu Sans.
# findfont: Font family ['Times New Roman'] not found. Falling back to DejaVu Sans.
# finished! total time: 2.226656913757324 s
# 0

# %%
root_path = "/ssd2/liuyixin04/workspace/logs/tmp/paddle-tmp-1650000382.5837822"
dic = {}
max_ = -9999900
min_ = 99999999
K={}
import pandas as pd
for p,d,f in os.walk(root_path):
    for fi in f:
        if '.csv' in fi:
            # print(fi)
            env = p.split('/')[-1]
            dic[env]={}
            dic[env]['max_y']=max_
            dic[env]['min_y']=min_
            K[env] = 4/5
for p,d,f in os.walk(root_path):
    for fi in f:
        env = p.split('/')[-1]
        if '.csv' in fi:
            df = pd.read_csv(os.path.join(p,fi))
            dic[env]['max_y'] = max(df['Value'].max(),dic[env]['max_y'])
            dic[env]['min_y'] = min(df['Value'].min(),dic[env]['min_y'])
dic
# Out:
# {'simple_adversary': {'max_y': 0.5830000042915344,
#   'min_y': -15.907999992370604},
#  'simple': {'max_y': -4.228000164031982, 'min_y': -45.16299819946289},
#  'simple_tag': {'max_y': 85.24199676513672, 'min_y': -13.512999534606934},
#  'simple_world_comm': {'max_y': 51.98199844360352, 'min_y': -93.8489990234375},
#  'simple_spread': {'max_y': -48.94200134277344, 'min_y': -188.5829925537109},
#  'simple_speaker_listener': {'max_y': -10.763999938964844,
#   'min_y': -115.99600219726562},
#  'simple_push': {'max_y': -6.500999927520752, 'min_y': -30.106000900268555},
#  'simple_crypto': {'max_y': 35.36800003051758, 'min_y': -40.31999969482422}}

# %%
for k,v in K.items():
    if k=="simple_tag":
        K[k] = 1/3

# %%
root_path = "/ssd2/liuyixin04/workspace/test-yixin/faster_exp_plot/plot_dir"

dic = {}
max_ = -9999900
min_ = 99999999
import pandas as pd
import numpy as np
for p,d,f in os.walk(root_path):
    for fi in f:
        if '.csv' in fi:
            # print(fi)
            env = p.split('/')[-1]
            dic[env]={}
            dic[env]['max_y']=max_
            dic[env]['min_y']=min_
            dic[env]['mean_endy']=[]
for p,d,f in os.walk(root_path):
    for fi in f:
        env = p.split('/')[-1]
        if '.csv' in fi:
            df = pd.read_csv(os.path.join(p,fi))
            dic[env]['max_y'] = max(df['Value'].max(),dic[env]['max_y'])
            dic[env]['min_y'] = min(df['Value'].min(),dic[env]['min_y'])
            dic[env]['mean_endy'].append(df['Value'].to_list()[-1])
for k,v in dic.items():
    import numpy as np
    dic[k]['mean_endy'] = np.mean(dic[k]['mean_endy'])
for k,v in dic.items():
    dic[k]['max_y'] = dic[k]['min_y'] + np.abs(dic[k]['mean_endy']-dic[k]['min_y'])/K[k]
    dic[k]['y_major_loc'] = np.abs(dic[k]['max_y']-dic[k]['min_y'])/4
dic
# Out:
# {'simple_adversary': {'max_y': 0.7554997876286507,
#   'min_y': -21.136999130249023,
#   'mean_endy': -3.622999995946884,
#   'y_major_loc': 5.4731247294694185},
#  'simple': {'max_y': 4.269678916249958,
#   'min_y': -44.4630012512207,
#   'mean_endy': -5.476857117244175,
#   'y_major_loc': 12.183170041867665},
#  'simple_tag': {'max_y': 40.08424925804138,
#   'min_y': -12.423999786376951,
#   'mean_endy': 5.078749895095825,
#   'y_major_loc': 13.127062261104584},
#  'simple_world_comm': {'max_y': 51.33162546157837,
#   'min_y': -77.28900146484375,
#   'mean_endy': 25.607500076293945,
#   'y_major_loc': 32.15515673160553},
#  'simple_spread': {'max_y': -95.54324913024902,
#   'min_y': -129.07200622558594,
#   'mean_endy': -102.2490005493164,
#   'y_major_loc': 8.382189273834229},
#  'simple_speaker_listener': {'max_y': -0.29268765449525347,
#   'min_y': -122.01300048828124,
#   'mean_endy': -24.63675022125244,
#   'y_major_loc': 30.430078208446496},
#  'simple_push': {'max_y': -2.0300001204013824,
#   'min_y': -30.56999969482422,
#   'mean_endy': -7.73800003528595,
#   'y_major_loc': 7.134999893605709},
#  'simple_crypto': {'max_y': -1.656843826174736,
#   'min_y': -40.75199890136719,
#   'mean_endy': -9.475874841213226,
#   'y_major_loc': 9.773788768798113}}
